# %% [markdown]
# <a href="https://colab.research.google.com/github/Amourya03/Amourya03/blob/main/English_To_Indic_Language_Translation_with_Hugging_Face_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### English to Hindi/Tammil/Telgu/Gujrati Translation With Hugging Face

# %% [markdown]
# #### Facebook mBart model is good to use for English to some Indic Language Translation.

# %% [markdown]
# ### This the link of the mBart model.
# https://huggingface.co/facebook/mbart-large-50-one-to-many-mmt
#
# ### Documentation:
# https://huggingface.co/docs/transformers/model_doc/mbart

# %%
# !pip install transformers -U -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 24.2 MB/s eta 0:00:00

# %%
! pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.1 MB/s eta 0:00:00
# ...

# %%
# !pip freeze | grep transformers
# Out:
# transformers==4.36.2

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

# %%
model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-one-to-many-mmt")
# Out:
# config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]

# %%
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-one-to-many-mmt", src_lang="en_XX")
# Out:
# tokenizer_config.json:   0%|          | 0.00/528 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/717 [00:00<?, ?B/s]

# %%
# english sentence which you want to convert
article_en = "I live in India."

# %%
model_inputs = tokenizer(article_en, return_tensors="pt")

# %%
# translate from English to Hindi
generated_tokens = model.generate(
    **model_inputs,
    forced_bos_token_id=tokenizer.lang_code_to_id["hi_IN"]
)

# %%
translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)

# %%
print(translation)
# Out:
# ['मैं भारत में रह रहा हूं।']

# %%
translation
# Out:
# ['मैं भारत में रह रहा हूं।']
